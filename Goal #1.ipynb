# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
path = os.path.join(os.getcwd(), "World_Bank_Projects_downloaded_11_2_2022.xls")

projects = pd.read_excel(path, header=2)

# %%
projects
# Out:
#             id                   regionname  \
# 0      P252350  Eastern and Southern Africa
# 1      P252338        East Asia and Pacific
# 2      P252337  Eastern and Southern Africa
# 3      P179942  Eastern and Southern Africa
# 4      P179918  Eastern and Southern Africa
# ...        ...                          ...
# 21675  P000019                       Africa
# 21676  P000017                       Africa
# 21677  P000010                       Africa
# 21678  P000003                       Africa
# 21679  P000001                       Africa
#
#                               countryname projectstatusdisplay  \
# 0                      Republic of Rwanda               Active
# 1      Democratic Republic of Timor-Leste               Active
# 2                       Republic of Kenya              Dropped
# 3                  Republic of Mozambique             Pipeline
# 4                 Republic of South Sudan             Pipeline
# ...                                   ...                  ...
# 21675                              Africa              Dropped
# 21676                              Africa               Closed
# 21677                              Africa               Closed
# 21678                              Africa               Closed
# 21679                              Africa               Closed
#
#       last_stage_reached_name  \
# 0               Bank Approved
# 1               Bank Approved
# 2              Concept Review
# 3                         NaN
# 4                         NaN
# ...                       ...
# 21675                     NaN
# 21676           Bank Approved
# 21677                     NaN
# 21678           Bank Approved
# 21679           Bank Approved
#
#                                             project_name  \
# 0                Rwanda Priority Skills for Growth (PSG)
# 1      Road Climate Resilience Project Second Additio...
# 2                  Kenya Devolution and Service Delivery
# 3                      Mozambique State Capacity Project
# 4      South Sudan Transport Sector Development and R...
# ...                                                  ...
# 21675            UEMOA Regional Financial Sector Project
# 21676       Engineering and Technical Assistance Project
# 21677                  Regional Development Project (03)
# 21678                                REIMP(CEN.ENV.INFO)
# 21679  West Africa Pilot Community-based Natural Reso...
#
#                                                      pdo  \
# 0      The Program Development Objective is to expand...
# 1      The project will deliver sustainable climate r...
# 2      To improve citizen and government access to co...
# 3      The project development objective is to streng...
# 4      To facilitate the recovery, regional integrati...
# ...                                                  ...
# 21675                                                NaN
# 21676                                                NaN
# 21677                                                NaN
# 21678                                                NaN
# 21679                                                NaN
#
#                                                impagency cons_serv_reqd_ind  \
# 0                                  Ministry Of Education                NaN
# 1      Ministry of Public Works, Transport, and Commu...                NaN
# 2                    Kenya National Bureau of Statistics                NaN
# 3                                                    NaN                NaN
# 4                                                    NaN                NaN
# ...                                                  ...                ...
# 21675                                                NaN                NaN
# 21676                                                NaN                NaN
# 21677                                                NaN                NaN
# 21678                                                NaN                NaN
# 21679                                                NaN                NaN
#
#                                                      url  ...    grantamt  \
# 0      http://projects.worldbank.org/P252350/null?lan...  ...         NaN
# 1      http://projects.worldbank.org/P252338/null?lan...  ...         NaN
# 2      http://projects.worldbank.org/P252337/null?lan...  ...         NaN
# 3      http://projects.worldbank.org/P179942/null?lan...  ...         NaN
# 4      http://projects.worldbank.org/P179918/null?lan...  ...         NaN
# ...                                                  ...  ...         ...
# 21675  http://projects.worldbank.org/P000019/null?lan...  ...         NaN
# 21676  http://projects.worldbank.org/P000017/engineer...  ...         NaN
# 21677  http://projects.worldbank.org/P000010/null?lan...  ...         NaN
# 21678  http://projects.worldbank.org/P000003/reimpcen...  ...         0.0
# 21679  http://projects.worldbank.org/P000001/west-afr...  ...  11400000.0
#
#                                         borrower  \
# 0      Ministry of Finance and Economic Planning
# 1                            Ministry of Finance
# 2            Kenya National Bureau of Statistics
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 21675                                        NaN
# 21676                                        NaN
# 21677                                        NaN
# 21678                                        NaN
# 21679                                        NaN
#
#                         lendinginstr  envassesmentcategorycode  \
# 0      Program-for-Results Financing                       NaN
# 1       Investment Project Financing                         B
# 2       Investment Project Financing                         C
# 3      Program-for-Results Financing                       NaN
# 4       Investment Project Financing                       NaN
# ...                              ...                       ...
# 21675       Specific Investment Loan                         C
# 21676      Technical Assistance Loan                         C
# 21677    Financial Intermediary Loan                         B
# 21678       Specific Investment Loan                         C
# 21679       Specific Investment Loan                         B
#
#        esrc_ovrl_risk_rate                            sector1  \
# 0                      NaN  Public Administration - Education
# 1                      NaN        Rural and Inter-Urban Roads
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
# ...                    ...                                ...
# 21675                  NaN                                NaN
# 21676                  NaN                              Power
# 21677                  NaN               Banking Institutions
# 21678                  NaN        Other Public Administration
# 21679                  NaN            Sub-National Government
#
#                                                  sector2  \
# 0                                     Tertiary Education
# 1                 Public Administration - Transportation
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 21675                                                NaN
# 21676                                                NaN
# 21677            Other Agriculture, Fishing and Forestry
# 21678  Other Information and Communications Technologies
# 21679                                  Social Protection
#
#                                               sector3  \
# 0      Workforce Development and Vocational Education
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 21675                                             NaN
# 21676                                             NaN
# 21677                            Other Transportation
# 21678                               Social Protection
# 21679         Other Agriculture, Fishing and Forestry
#
#                                                   theme1  \
# 0                    Education for the knowledge economy
# 1                                                    NaN
# 2      Public expenditure, financial management and p...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 21675                                                NaN
# 21676            Legal institutions for a market economy
# 21677            Environmental policies and institutions
# 21678                 Land administration and management
# 21679                  Rural services and infrastructure
#
#                                                   theme2
# 0                                                    NaN
# 1                                                    NaN
# 2                                       Decentralization
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 21675                                                NaN
# 21676  Infrastructure services for private sector dev...
# 21677     Other financial and private sector development
# 21678            Environmental policies and institutions
# 21679                                       Biodiversity
#
# [21680 rows x 27 columns]
