# %%
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Imports file containing projects
path = os.path.join(os.getcwd(), "World_Bank_Projects_Cleaned.csv")

projects = pd.read_csv(path)

# %%
# projects.head()

# %% [markdown]
# ## 1) Identify total number of projects in each sector

# %%
sector_counts = projects["Generalized Sector"].value_counts()

# %%
sector_labels = list(sector_counts.keys())
sector_label_values = list(sector_counts.values)

# %%
# Graphs each unique sector, and number of projects per sector
plt.bar(sector_counts.keys(), sector_counts.values)

plt.show()

# %% [markdown]
# ## 2) Identify # of projects per country

# %%
country = projects['Country'].value_counts().to_dict()
pd.DataFrame.from_dict(country, orient="index")
# Out:
#                                             0
# Republic of India                         927
# Republic of Indonesia                     650
# People's Republic of China                610
# Federative Republic of Brazil             580
# Islamic Republic of Pakistan              499
# ...                                       ...
# American Samoa                              1
# South East Asia -BN, MY, PH, TH             1
# Antigua and Barbuda                         1
# Republic of Malta                           1
# Socialist People's Libyan Arab Jamahiriy    1
#
# [208 rows x 1 columns]

# %%
temp = projects[projects["Project Status"]=="Closed"]
temp["Last Stage Reached Name"].unique()
# Out:
# array(['Bank Approved', nan, 'Concept Review', 'Begin Negotiation',
#        'Decision Meeting', 'Begin Appraisal'], dtype=object)

# %%
temp
# Out:
#       Project ID                       Region                      Country  \
# 649      P177191        East Asia and Pacific  Republic of the Philippines
# 789      P176756        East Asia and Pacific          Kingdom of Cambodia
# 810      P176694                   South Asia                        Nepal
# 835      P176616                   South Asia                        Nepal
# 877      P176454      Europe and Central Asia          Republic of Armenia
# ...          ...                          ...                          ...
# 21671    P000034  Eastern and Southern Africa           Republic of Angola
# 21676    P000017                       Africa                       Africa
# 21677    P000010                       Africa                       Africa
# 21678    P000003                       Africa                       Africa
# 21679    P000001                       Africa                       Africa
#
#       Project Status Last Stage Reached Name  \
# 649           Closed           Bank Approved
# 789           Closed           Bank Approved
# 810           Closed           Bank Approved
# 835           Closed           Bank Approved
# 877           Closed           Bank Approved
# ...              ...                     ...
# 21671         Closed           Bank Approved
# 21676         Closed           Bank Approved
# 21677         Closed                     NaN
# 21678         Closed           Bank Approved
# 21679         Closed           Bank Approved
#
#                                             Project Name  \
# 649              Philippines Conflict Monitoring Project
# 789    Cambodia Relief, Recovery and Resilience Devel...
# 810    Additional Financing for Nepal Health Sector M...
# 835                         Additional Financing to SSDP
# 877    Armenia Support to Conflict Affected Families ...
# ...                                                  ...
# 21671  Infrastructure Rehabilitation Engineering Proj...
# 21676       Engineering and Technical Assistance Project
# 21677                  Regional Development Project (03)
# 21678                                REIMP(CEN.ENV.INFO)
# 21679  West Africa Pilot Community-based Natural Reso...
#
#                           Project Development Objective   \
# 649    To provide useful, timely, and reliable confli...
# 789    The program development objective is to suppor...
# 810    The Program Development Objective is to improv...
# 835    The Program Development Objective is to improv...
# 877    The grant development objective is to improve ...
# ...                                                  ...
# 21671                                                NaN
# 21676                                                NaN
# 21677                                                NaN
# 21678                                                NaN
# 21679                                                NaN
#
#                                  Implementing Agency  \
# 649                              International Alert
# 789                  Ministry of Economy and Finance
# 810                Ministry of Health and Population
# 835    Ministry of Education, Science and Technology
# 877             Ministry of Labor and Social Affairs
# ...                                              ...
# 21671                                            NaN
# 21676                                            NaN
# 21677                                            NaN
# 21678                                            NaN
# 21679                                            NaN
#
#       Consultant Services Required  \
# 649                            NaN
# 789                            NaN
# 810                            NaN
# 835                            NaN
# 877                              N
# ...                            ...
# 21671                          NaN
# 21676                          NaN
# 21677                          NaN
# 21678                          NaN
# 21679                          NaN
#
#                                              Project URL  ...  \
# 649    http://projects.worldbank.org/P177191/null?lan...  ...
# 789    http://projects.worldbank.org/P176756/null?lan...  ...
# 810    http://projects.worldbank.org/P176694/null?lan...  ...
# 835    http://projects.worldbank.org/P176616/null?lan...  ...
# 877    http://projects.worldbank.org/P176454/null?lan...  ...
# ...                                                  ...  ...
# 21671  http://projects.worldbank.org/P000034/infrastr...  ...
# 21676  http://projects.worldbank.org/P000017/engineer...  ...
# 21677  http://projects.worldbank.org/P000010/null?lan...  ...
# 21678  http://projects.worldbank.org/P000003/reimpcen...  ...
# 21679  http://projects.worldbank.org/P000001/west-afr...  ...
#
#       Current Project Cost IBRD Commitment  IDA Commitment  \
# 649           7.400000e+05              0.0            0.0
# 789           2.000000e+08              0.0    200000000.0
# 810           7.610600e+08              0.0     50000000.0
# 835           1.045600e+09              0.0     50000000.0
# 877           3.720000e+06              0.0            0.0
# ...                    ...              ...            ...
# 21671         3.210000e+07              0.0     37700000.0
# 21676         6.100000e+06              0.0      5500000.0
# 21677         5.500000e+07       15000000.0     40000000.0
# 21678         1.970000e+07              0.0            0.0
# 21679         7.000000e+06              0.0            0.0
#
#        Total IDA and IBRD Commitment  Grant Amount  \
# 649                              0.0      740000.0
# 789                      200000000.0           NaN
# 810                       50000000.0           NaN
# 835                       50000000.0           NaN
# 877                              0.0     3720000.0
# ...                              ...           ...
# 21671                     37700000.0           NaN
# 21676                      5500000.0           NaN
# 21677                     55000000.0           NaN
# 21678                            0.0           0.0
# 21679                            0.0    11400000.0
#
#                                                 Borrower  \
# 649                                  International Alert
# 789                                  Kingdom of Cambodia
# 810                                  Ministry of Finance
# 835    Nepal Ministry of Education, Science and Techn...
# 877                                  Republic of Armenia
# ...                                                  ...
# 21671                                                NaN
# 21676                                                NaN
# 21677                                                NaN
# 21678                                                NaN
# 21679                                                NaN
#
#                   Lending Instrument  Environmental Assessment Category  \
# 649     Investment Project Financing                                NaN
# 789       Development Policy Lending                                NaN
# 810    Program-for-Results Financing                                NaN
# 835    Program-for-Results Financing                                NaN
# 877     Investment Project Financing                                NaN
# ...                              ...                                ...
# 21671      Technical Assistance Loan                                  C
# 21676      Technical Assistance Loan                                  C
# 21677    Financial Intermediary Loan                                  B
# 21678       Specific Investment Loan                                  C
# 21679       Specific Investment Loan                                  B
#
#       Environmental and Social Risk           Generalized Sector
# 649                        Moderate                        Other
# 789                             NaN  Institutions and Governance
# 810                             NaN                       Health
# 835                             NaN                    Education
# 877                        Moderate                        Other
# ...                             ...                          ...
# 21671                           NaN               Transportation
# 21676                           NaN                       Energy
# 21677                           NaN                     Economic
# 21678                           NaN                        Other
# 21679                           NaN  Institutions and Governance
#
# [16218 rows x 23 columns]
