# %%
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns

# %%
# Imports file containing projects
path = os.path.join(os.getcwd(), "World_Bank_Projects_Cleaned.csv")

projects = pd.read_csv(path)

# %%
projects.head()
# Out:
#    Unnamed: 0 Project ID                       Region  \
# 0           1    P252350  Eastern and Southern Africa
# 1           2    P252338        East Asia and Pacific
# 2           3    P252337  Eastern and Southern Africa
# 3           4    P179942  Eastern and Southern Africa
# 4           5    P179918  Eastern and Southern Africa
#
#                               Country Project Status Last Stage Reached Name  \
# 0                  Republic of Rwanda         Active           Bank Approved
# 1  Democratic Republic of Timor-Leste         Active           Bank Approved
# 2                   Republic of Kenya        Dropped          Concept Review
# 3              Republic of Mozambique       Pipeline                     NaN
# 4             Republic of South Sudan       Pipeline                     NaN
#
#                                         Project Name  \
# 0            Rwanda Priority Skills for Growth (PSG)
# 1  Road Climate Resilience Project Second Additio...
# 2              Kenya Devolution and Service Delivery
# 3                  Mozambique State Capacity Project
# 4  South Sudan Transport Sector Development and R...
#
#                       Project Development Objective   \
# 0  The Program Development Objective is to expand...
# 1  The project will deliver sustainable climate r...
# 2  To improve citizen and government access to co...
# 3  The project development objective is to streng...
# 4  To facilitate the recovery, regional integrati...
#
#                                  Implementing Agency  \
# 0                              Ministry Of Education
# 1  Ministry of Public Works, Transport, and Commu...
# 2                Kenya National Bureau of Statistics
# 3                                                NaN
# 4                                                NaN
#
#   Consultant Services Required  ... Current Project Cost IBRD Commitment   \
# 0                          NaN  ...          120000000.0              0.0
# 1                          NaN  ...           39140000.0              0.0
# 2                          NaN  ...             340000.0              0.0
# 3                          NaN  ...          200000000.0              0.0
# 4                          NaN  ...           40000000.0              0.0
#
#   IDA Commitment Total IDA and IBRD Commitment  Grant Amount  \
# 0    120000000.0                   120000000.0           NaN
# 1     35200000.0                    35200000.0           NaN
# 2            0.0                           0.0           NaN
# 3    200000000.0                   200000000.0           NaN
# 4     40000000.0                    40000000.0           NaN
#
#                                     Borrower             Lending Instrument  \
# 0  Ministry of Finance and Economic Planning  Program-for-Results Financing
# 1                        Ministry of Finance   Investment Project Financing
# 2        Kenya National Bureau of Statistics   Investment Project Financing
# 3                                        NaN  Program-for-Results Financing
# 4                                        NaN   Investment Project Financing
#
#    Environmental Assessment Category  Environmental and Social Risk  \
# 0                                NaN                            NaN
# 1                                  B                            NaN
# 2                                  C                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   Generalized Sector
# 0          Education
# 1     Infrastructure
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 24 columns]

# %%
country = projects['Country'].value_counts().to_dict()
pd.DataFrame.from_dict(country, orient="index")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 country = projects['Country'].value_counts().to_dict()
#       2 pd.DataFrame.from_dict(country, orient="index")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Country'

# %%
temp = projects[projects["Project Status"]=="Closed"]
temp["Last Stage Reached Name"].unique()
# Out:
# array(['Bank Approved', nan, 'Concept Review', 'Begin Negotiation',
#        'Decision Meeting', 'Begin Appraisal'], dtype=object)

# %%
temp
# Out:
#       Project ID                       Region                      Country  \
# 650      P177191        East Asia and Pacific  Republic of the Philippines
# 790      P176756        East Asia and Pacific          Kingdom of Cambodia
# 811      P176694                   South Asia                        Nepal
# 836      P176616                   South Asia                        Nepal
# 878      P176454      Europe and Central Asia          Republic of Armenia
# ...          ...                          ...                          ...
# 21672    P000034  Eastern and Southern Africa           Republic of Angola
# 21677    P000017                       Africa                       Africa
# 21678    P000010                       Africa                       Africa
# 21679    P000003                       Africa                       Africa
# 21680    P000001                       Africa                       Africa
#
#       Project Status Last Stage Reached Name  \
# 650           Closed           Bank Approved
# 790           Closed           Bank Approved
# 811           Closed           Bank Approved
# 836           Closed           Bank Approved
# 878           Closed           Bank Approved
# ...              ...                     ...
# 21672         Closed           Bank Approved
# 21677         Closed           Bank Approved
# 21678         Closed                     NaN
# 21679         Closed           Bank Approved
# 21680         Closed           Bank Approved
#
#                                             Project Name  \
# 650              Philippines Conflict Monitoring Project
# 790    Cambodia Relief, Recovery and Resilience Devel...
# 811    Additional Financing for Nepal Health Sector M...
# 836                         Additional Financing to SSDP
# 878    Armenia Support to Conflict Affected Families ...
# ...                                                  ...
# 21672  Infrastructure Rehabilitation Engineering Proj...
# 21677       Engineering and Technical Assistance Project
# 21678                  Regional Development Project (03)
# 21679                                REIMP(CEN.ENV.INFO)
# 21680  West Africa Pilot Community-based Natural Reso...
#
#                           Project Development Objective   \
# 650    To provide useful, timely, and reliable confli...
# 790    The program development objective is to suppor...
# 811    The Program Development Objective is to improv...
# 836    The Program Development Objective is to improv...
# 878    The grant development objective is to improve ...
# ...                                                  ...
# 21672                                                NaN
# 21677                                                NaN
# 21678                                                NaN
# 21679                                                NaN
# 21680                                                NaN
#
#                                  Implementing Agency  \
# 650                              International Alert
# 790                  Ministry of Economy and Finance
# 811                Ministry of Health and Population
# 836    Ministry of Education, Science and Technology
# 878             Ministry of Labor and Social Affairs
# ...                                              ...
# 21672                                            NaN
# 21677                                            NaN
# 21678                                            NaN
# 21679                                            NaN
# 21680                                            NaN
#
#       Consultant Services Required  \
# 650                            NaN
# 790                            NaN
# 811                            NaN
# 836                            NaN
# 878                              N
# ...                            ...
# 21672                          NaN
# 21677                          NaN
# 21678                          NaN
# 21679                          NaN
# 21680                          NaN
#
#                                              Project URL  \
# 650    http://projects.worldbank.org/P177191/null?lan...
# 790    http://projects.worldbank.org/P176756/null?lan...
# 811    http://projects.worldbank.org/P176694/null?lan...
# 836    http://projects.worldbank.org/P176616/null?lan...
# 878    http://projects.worldbank.org/P176454/null?lan...
# ...                                                  ...
# 21672  http://projects.worldbank.org/P000034/infrastr...
# 21677  http://projects.worldbank.org/P000017/engineer...
# 21678  http://projects.worldbank.org/P000010/null?lan...
# 21679  http://projects.worldbank.org/P000003/reimpcen...
# 21680  http://projects.worldbank.org/P000001/west-afr...
#
#         Board Approval Date    Project Closing Date Financing Type  \
# 650    2021-10-14T00:00:00Z   6/30/2022 12:00:00 AM         Grants
# 790    2021-06-24T00:00:00Z   5/31/2022 12:00:00 AM            IDA
# 811    2021-07-08T00:00:00Z                     NaN          Other
# 836    2021-07-08T00:00:00Z                     NaN          Other
# 878    2021-04-22T00:00:00Z   5/31/2022 12:00:00 AM         Grants
# ...                     ...                     ...            ...
# 21672  1991-07-16T00:00:00Z   3/31/1999 12:00:00 AM            IDA
# 21677  1992-05-19T00:00:00Z  12/31/1999 12:00:00 AM            IDA
# 21678  1990-02-01T00:00:00Z  12/31/1997 12:00:00 AM            NaN
# 21679  1997-12-18T00:00:00Z   6/30/2003 12:00:00 AM          Other
# 21680  1995-09-14T00:00:00Z   6/30/2004 12:00:00 AM          Other
#
#       Current Project Cost IBRD Commitment  IDA Commitment  \
# 650                 740000                0              0
# 790              200000000                0      200000000
# 811              761060000                0       50000000
# 836             1045600000                0       50000000
# 878                3720000                0              0
# ...                    ...              ...            ...
# 21672             32100000                0       37700000
# 21677              6100000                0        5500000
# 21678             55000000         15000000       40000000
# 21679             19700000                0              0
# 21680              7000000                0              0
#
#       Total IDA and IBRD Commitment Grant Amount  \
# 650                               0       740000
# 790                       200000000          NaN
# 811                        50000000          NaN
# 836                        50000000          NaN
# 878                               0      3720000
# ...                             ...          ...
# 21672                      37700000          NaN
# 21677                       5500000          NaN
# 21678                      55000000          NaN
# 21679                             0            0
# 21680                             0     11400000
#
#                                                 Borrower  \
# 650                                  International Alert
# 790                                  Kingdom of Cambodia
# 811                                  Ministry of Finance
# 836    Nepal Ministry of Education, Science and Techn...
# 878                                  Republic of Armenia
# ...                                                  ...
# 21672                                                NaN
# 21677                                                NaN
# 21678                                                NaN
# 21679                                                NaN
# 21680                                                NaN
#
#                   Lending Instrument Environmental Assessment Category  \
# 650     Investment Project Financing                               NaN
# 790       Development Policy Lending                               NaN
# 811    Program-for-Results Financing                               NaN
# 836    Program-for-Results Financing                               NaN
# 878     Investment Project Financing                               NaN
# ...                              ...                               ...
# 21672      Technical Assistance Loan                                 C
# 21677      Technical Assistance Loan                                 C
# 21678    Financial Intermediary Loan                                 B
# 21679       Specific Investment Loan                                 C
# 21680       Specific Investment Loan                                 B
#
#       Environmental and Social Risk  \
# 650                        Moderate
# 790                             NaN
# 811                             NaN
# 836                             NaN
# 878                        Moderate
# ...                             ...
# 21672                           NaN
# 21677                           NaN
# 21678                           NaN
# 21679                           NaN
# 21680                           NaN
#
#                                         Sector 1  \
# 650    Public Administration - Social Protection
# 790        Central Government (Central Agencies)
# 811                                       Health
# 836            Public Administration - Education
# 878                            Social Protection
# ...                                          ...
# 21672                                   Railways
# 21677                                      Power
# 21678                       Banking Institutions
# 21679                Other Public Administration
# 21680                    Sub-National Government
#
#                                                 Sector 2  \
# 650                                                  NaN
# 790                                 Banking Institutions
# 811                       Public Administration - Health
# 836                                  Secondary Education
# 878            Public Administration - Social Protection
# ...                                                  ...
# 21672                                 Roads and highways
# 21677                                                NaN
# 21678            Other Agriculture, Fishing and Forestry
# 21679  Other Information and Communications Technologies
# 21680                                  Social Protection
#
#                                       Sector 3  \
# 650                                        NaN
# 790                          Social Protection
# 811                                        NaN
# 836                          Primary Education
# 878                                        NaN
# ...                                        ...
# 21672                          Ports/Waterways
# 21677                                      NaN
# 21678                     Other Transportation
# 21679                        Social Protection
# 21680  Other Agriculture, Fishing and Forestry
#
#                                        Theme 1  \
# 650                                        NaN
# 790                                        NaN
# 811                                        NaN
# 836                                        NaN
# 878                                        NaN
# ...                                        ...
# 21672                  Other urban development
# 21677  Legal institutions for a market economy
# 21678  Environmental policies and institutions
# 21679       Land administration and management
# 21680        Rural services and infrastructure
#
#                                                  Theme 2
# 650                                                  NaN
# 790                                                  NaN
# 811                                                  NaN
# 836                                                  NaN
# 878                                                  NaN
# ...                                                  ...
# 21672                  Rural services and infrastructure
# 21677  Infrastructure services for private sector dev...
# 21678     Other financial and private sector development
# 21679            Environmental policies and institutions
# 21680                                       Biodiversity
#
# [16218 rows x 27 columns]
